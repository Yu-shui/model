# %%
import os

# %%
path='./beifen.txt'
path2='./after.txt'

# %%
num=1
n=1
with open(path) as f:
    with open(path2,'w') as f2:
        for line in f:
            if len(line)>10 and line[0]=='[':
                n+=1
                s=list(line)
                count=0
                for i in range(len(s)):
                    if s[i]==']':
                        if count==0:
                            s[i]=''
                            count+=1
                        elif count==1:
                            s[i]='#'
                            break
                    elif s[i]=='[':
                        s[i]='#'
                count=0
                for i in range(len(s)):
                    if s[i]==',':
                        if count==0:
                            s[i]='_'
                            s[i+1]=''
                            count+=1
                        elif count==1:
                            s[i]='_'
                            s[i+1]=''
                            break
                line="".join(s)
            print(line)
            f2.write(line)
# Out:
# "GLd3aX16zBg": "duration": 241.62, "subset": "training", "recipe_type": "113", "annotations":
#
# #114_127#132_138#place the bread slices on top of each other, not a slice of cheese
#
# #139_145#173_174#cut the sandwich in half, not flip it over
#
#
#
#
#
# "xHr8X2Wpmno": "duration": 206.86, "subset": "validation", "recipe_type": "226", "annotations":
#
# #47_60#99_137#add verdalago pepper to the lettuce in the bowl, not pick the ends off it
#
#
#
#
#
# "V53XmPeyjIU":
#
# "duration": 189.36, "subset": "validation", "recipe_type": "105", "annotations": [
#
# #33_36#46_53#rinse chicken off thoroughly, not place in a small bowl.
#
# #60_89#108_129#coat the chicken pieces in the flour, not place it on a plate.
#
#
#
#
#
#  "mZwK0TBI1iY":
#
# "duration": 264.95, "subset": "validation", "recipe_type": "201", "annotations": [
#
# #44_55#55_78#rub flour onto the chicken, not salt.
#
# #78_96#102_107#top the chicken with mozzarella cheese, not fry it in a pan"
#
# ...

# %%
print(n)
# Out:
# 1394

# %%
ccc=0
with open(path) as f:
    for line in f:
        if line[0]=='#' or line[0]=='[':
            ccc+=1

# %%
print(ccc)
# Out:
# 2077

# %%
import torch
import torch.nn as nn

# %%
n1 = torch.FloatTensor([[1,2][2,3]])
n2 = torch.FloatTensor([[4,5][7,8]])
loss = torch.nn.L1Loss()
loss_
